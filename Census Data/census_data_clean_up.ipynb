# %%
import pandas as pd

# %%
file_path = "census_data.csv"

# Read the mouse data and the study results
census_df = pd.read_csv(file_path)
census_df.head()
# Out:
#           Name  median_household_income  total_population  median_age  \
# 0  ZCTA5 00601                  17113.0           14361.0        41.9
# 1  ZCTA5 00602                  37751.0           16807.0        42.9
# 2  ZCTA5 00603                  47081.0           16049.0        42.1
# 3  ZCTA5 00606                   6392.0           12119.0        44.3
# 4  ZCTA5 00610                  26686.0           19898.0        42.7
#
#    per_capita  median_gross_rent  median_home_value  education_none  \
# 0      7493.0              383.0            83900.0           455.0
# 1      9694.0              400.0            85300.0           822.0
# 2     11259.0              433.0           118400.0           804.0
# 3      6093.0              275.0            80800.0           236.0
# 4     10572.0              427.0            87600.0           744.0
#
#    education_high_school  education_ged  education_associates  \
# 0                 2952.0          199.0                1141.0
# ...

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264960 entries, 0 to 264959
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Name                     264960 non-null  object
#  1   median_household_income  264960 non-null  float64
#  2   total_population         263962 non-null  float64
#  3   median_age               264960 non-null  float64
#  4   per_capita               262723 non-null  float64
#  5   median_gross_rent        264512 non-null  float64
#  6   median_home_value        264129 non-null  float64
#  7   education_none           264960 non-null  float64
#  8   education_high_school    264960 non-null  float64
#  9   education_ged            264960 non-null  float64
#  10  education_associates     264960 non-null  float64
#  11  education_bachelors      264960 non-null  float64
#  12  education_masters        264960 non-null  float64
# ...

# %%
census_df.describe()
# Out:
#        median_household_income  total_population    median_age    per_capita  \
# count            264960.000000      2.639620e+05  2.649600e+05  2.627230e+05
# mean               9686.955582     -3.245475e+07 -1.048204e+07 -6.562413e+06
# std               14287.965161      1.435905e+08  8.293497e+07  6.595648e+07
# min                   0.000000     -6.666667e+08 -6.666667e+08 -6.666667e+08
# 25%                 714.000000      3.838700e+04  3.630000e+01  2.032800e+04
# 50%                2803.000000      4.950500e+04  4.140000e+01  2.520300e+04
# 75%               13180.000000      6.324375e+04  4.660000e+01  3.171200e+04
# max              128294.000000      2.500010e+05  1.051000e+02  5.014330e+05
#
#        median_gross_rent  median_home_value  education_none  \
# count       2.645120e+05       2.641290e+05   264960.000000
# mean       -1.120723e+08      -3.941874e+07       91.975615
# std         2.493098e+08       1.576044e+08      237.677878
# ...

# %%
#get rid of populations with less 0 individuals (census data places -66666666.0 as a null value)
mask= census_df.total_population >=0
census_df2= census_df.loc[mask]
census_df2
# Out:
#                Name  median_household_income  total_population  median_age  \
# 0       ZCTA5 00601                  17113.0           14361.0        41.9
# 1       ZCTA5 00602                  37751.0           16807.0        42.9
# 2       ZCTA5 00603                  47081.0           16049.0        42.1
# 3       ZCTA5 00606                   6392.0           12119.0        44.3
# 4       ZCTA5 00610                  26686.0           19898.0        42.7
# ...             ...                      ...               ...         ...
# 264955  ZCTA5 97035                  23820.0           72883.0        41.9
# 264956  ZCTA5 97037                    882.0           41048.0        50.8
# 264957  ZCTA5 97038                  15265.0           54225.0        35.7
# 264958  ZCTA5 97039                    411.0           33056.0        46.4
# 264959  ZCTA5 97040                   1254.0           54155.0        37.9
#
# ...

# %%
#number of rows dropped
264960-251091
# Out:
# 13869

# %%
census_df2.describe()
# Out:
#        median_household_income  total_population    median_age     per_capita  \
# count            251091.000000     251091.000000  2.510910e+05  251049.000000
# mean              10201.002776      55146.585477 -7.923230e+03   27975.738748
# std               14502.350445      23884.869700  2.304369e+06   12600.489628
# min                   4.000000       2499.000000 -6.666667e+08     409.000000
# 25%                 880.000000      40204.500000  3.680000e+01   20674.000000
# 50%                3215.000000      50580.000000  4.150000e+01   25411.000000
# 75%               14313.000000      64167.000000  4.650000e+01   31860.000000
# max              128294.000000     250001.000000  1.051000e+02  465868.000000
#
#        median_gross_rent  median_home_value  education_none  \
# count       2.506620e+05       2.504710e+05   251091.000000
# mean       -8.357794e+07      -1.362034e+07       96.980660
# std         2.207579e+08       9.493813e+07      243.166072
# ...

# %%
#get rid of "null" values from median_age
mask = census_df2.median_age >=0
census_df3= census_df2.loc[mask]
census_df3
# Out:
#                Name  median_household_income  total_population  median_age  \
# 0       ZCTA5 00601                  17113.0           14361.0        41.9
# 1       ZCTA5 00602                  37751.0           16807.0        42.9
# 2       ZCTA5 00603                  47081.0           16049.0        42.1
# 3       ZCTA5 00606                   6392.0           12119.0        44.3
# 4       ZCTA5 00610                  26686.0           19898.0        42.7
# ...             ...                      ...               ...         ...
# 264955  ZCTA5 97035                  23820.0           72883.0        41.9
# 264956  ZCTA5 97037                    882.0           41048.0        50.8
# 264957  ZCTA5 97038                  15265.0           54225.0        35.7
# 264958  ZCTA5 97039                    411.0           33056.0        46.4
# 264959  ZCTA5 97040                   1254.0           54155.0        37.9
#
# ...

# %%
#number of rows dropped
251091-251088
# Out:
# 3

# %%
#get rid of "null" values from median_gross_rent
mask = census_df3.median_gross_rent <=0
census_df4=census_df3.loc[mask]
census_df4
# Out:
#                Name  median_household_income  total_population  median_age  \
# 86      ZCTA5 00786                    360.0           37552.0        54.0
# 91      ZCTA5 00906                    191.0          106518.0        35.6
# 133     ZCTA5 01003                  11357.0            2499.0        19.9
# 136     ZCTA5 01008                   1140.0           76333.0        54.0
# 137     ZCTA5 01009                    261.0           80714.0        53.4
# ...             ...                      ...               ...         ...
# 264888  ZCTA5 96773                    238.0           95069.0        48.4
# 264889  ZCTA5 96774                    408.0           47902.0        33.2
# 264923  ZCTA5 96860                    924.0           35227.0        22.7
# 264948  ZCTA5 97028                    133.0          250001.0        59.6
# 264953  ZCTA5 97033                     43.0           63333.0        63.2
#
# ...

# %%
#number of rows dropped
251088-219237
# Out:
# 31851

# %%
#get rid of "null" values from median_home_value
mask= census_df4.median_home_value >=0
census_df5= census_df4.loc[mask]
census_df5
# Out:
#                Name  median_household_income  total_population  median_age  \
# 0       ZCTA5 00601                  17113.0           14361.0        41.9
# 1       ZCTA5 00602                  37751.0           16807.0        42.9
# 2       ZCTA5 00603                  47081.0           16049.0        42.1
# 3       ZCTA5 00606                   6392.0           12119.0        44.3
# 4       ZCTA5 00610                  26686.0           19898.0        42.7
# ...             ...                      ...               ...         ...
# 264955  ZCTA5 97035                  23820.0           72883.0        41.9
# 264956  ZCTA5 97037                    882.0           41048.0        50.8
# 264957  ZCTA5 97038                  15265.0           54225.0        35.7
# 264958  ZCTA5 97039                    411.0           33056.0        46.4
# 264959  ZCTA5 97040                   1254.0           54155.0        37.9
#
# ...

# %%
#number of rows dropped
219237-216874
# Out:
# 2363

# %%
census_df5.describe()
# Out:
#        median_household_income  total_population     median_age  \
# count            216874.000000     216874.000000  216874.000000
# mean              11715.600266      55389.931896      41.303913
# std               15047.656438      23007.145564       7.186589
# min                  18.000000       2499.000000       8.900000
# 25%                1436.000000      40723.250000      36.600000
# 50%                4669.000000      50795.000000      41.100000
# 75%               17293.000000      64167.000000      45.500000
# max              128294.000000     250001.000000      86.300000
#
#           per_capita  median_gross_rent  median_home_value  education_none  \
# count  216874.000000      216874.000000       2.168740e+05   216874.000000
# mean    28100.855506         846.131708       1.848771e+05      111.779688
# std     12110.722270         347.652923       1.611531e+05      258.526871
# min      3037.000000          99.000000       9.999000e+03        0.000000
# ...

# %%
census_df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216874 entries, 0 to 264959
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Name                     216874 non-null  object
#  1   median_household_income  216874 non-null  float64
#  2   total_population         216874 non-null  float64
#  3   median_age               216874 non-null  float64
#  4   per_capita               216874 non-null  float64
#  5   median_gross_rent        216874 non-null  float64
#  6   median_home_value        216874 non-null  float64
#  7   education_none           216874 non-null  float64
#  8   education_high_school    216874 non-null  float64
#  9   education_ged            216874 non-null  float64
#  10  education_associates     216874 non-null  float64
#  11  education_bachelors      216874 non-null  float64
#  12  education_masters        216874 non-null  float64
# ...

# %%
census_df5
# Out:
#                Name  median_household_income  total_population  median_age  \
# 0       ZCTA5 00601                  17113.0           14361.0        41.9
# 1       ZCTA5 00602                  37751.0           16807.0        42.9
# 2       ZCTA5 00603                  47081.0           16049.0        42.1
# 3       ZCTA5 00606                   6392.0           12119.0        44.3
# 4       ZCTA5 00610                  26686.0           19898.0        42.7
# ...             ...                      ...               ...         ...
# 264955  ZCTA5 97035                  23820.0           72883.0        41.9
# 264956  ZCTA5 97037                    882.0           41048.0        50.8
# 264957  ZCTA5 97038                  15265.0           54225.0        35.7
# 264958  ZCTA5 97039                    411.0           33056.0        46.4
# 264959  ZCTA5 97040                   1254.0           54155.0        37.9
#
# ...

# %%
#Save as a csv
census_df3.to_csv("census_data_cleaned.csv", encoding="utf-8", index=False)
